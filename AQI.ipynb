# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as plt
# %matplotlib inline

# %%
url = 'https://raw.githubusercontent.com/TheValour/Machine_Learning/main/city_day.csv'
datafram = pd.read_csv(url)
datafram.head()
# Out:
#         City        Date  PM2.5  PM10     NO    NO2    NOx  NH3     CO    SO2  \
# 0  Ahmedabad  2015-01-01    NaN   NaN   0.92  18.22  17.15  NaN   0.92  27.64
# 1  Ahmedabad  2015-01-02    NaN   NaN   0.97  15.69  16.46  NaN   0.97  24.55
# 2  Ahmedabad  2015-01-03    NaN   NaN  17.40  19.30  29.70  NaN  17.40  29.07
# 3  Ahmedabad  2015-01-04    NaN   NaN   1.70  18.48  17.97  NaN   1.70  18.59
# 4  Ahmedabad  2015-01-05    NaN   NaN  22.10  21.42  37.76  NaN  22.10  39.33
#
#        O3  Benzene  Toluene  Xylene  AQI AQI_Bucket
# 0  133.36     0.00     0.02    0.00  NaN        NaN
# 1   34.06     3.68     5.50    3.77  NaN        NaN
# 2   30.70     6.80    16.40    2.25  NaN        NaN
# 3   36.08     4.43    10.14    1.00  NaN        NaN
# 4   39.31     7.01    18.89    2.78  NaN        NaN

# %% [markdown]
# ## Data Visulization 😊

# %%
datafram.isnull().sum()
# Out:
# City              0
# Date              0
# PM2.5          4598
# PM10          11140
# NO             3582
# NO2            3585
# NOx            4185
# NH3           10328
# CO             2059
# SO2            3854
# O3             4022
# Benzene        5623
# Toluene        8041
# Xylene        18109
# AQI            4681
# AQI_Bucket     4681
# dtype: int64

# %%
datafram.describe()
# Out:
#               PM2.5          PM10            NO           NO2           NOx  \
# count  24933.000000  18391.000000  25949.000000  25946.000000  25346.000000
# mean      67.450578    118.127103     17.574730     28.560659     32.309123
# std       64.661449     90.605110     22.785846     24.474746     31.646011
# min        0.040000      0.010000      0.020000      0.010000      0.000000
# 25%       28.820000     56.255000      5.630000     11.750000     12.820000
# 50%       48.570000     95.680000      9.890000     21.690000     23.520000
# 75%       80.590000    149.745000     19.950000     37.620000     40.127500
# max      949.990000   1000.000000    390.680000    362.210000    467.630000
#
#                 NH3            CO           SO2            O3       Benzene  \
# count  19203.000000  27472.000000  25677.000000  25509.000000  23908.000000
# mean      23.483476      2.248598     14.531977     34.491430      3.280840
# ...

# %%
datafram["Date"]
# Out:
# 0        2015-01-01
# 1        2015-01-02
# 2        2015-01-03
# 3        2015-01-04
# 4        2015-01-05
#             ...
# 29526    2020-06-27
# 29527    2020-06-28
# 29528    2020-06-29
# 29529    2020-06-30
# 29530    2020-07-01
# Name: Date, Length: 29531, dtype: object

# %%
sns.heatmap(datafram.isnull(),yticklabels=False,cmap='plasma')
# Out:
# <Axes: >

# %% [markdown]
# ### converting dtype of date column to datetime

# %%
df = datafram.copy()

# %%
df['Date']=df['Date'].apply(pd.to_datetime)

#setting date column as index
df.set_index('Date',inplace=True)

# %%
df
# Out:
#                      City  PM2.5   PM10     NO    NO2    NOx    NH3     CO  \
# Date
# 2015-01-01      Ahmedabad    NaN    NaN   0.92  18.22  17.15    NaN   0.92
# 2015-01-02      Ahmedabad    NaN    NaN   0.97  15.69  16.46    NaN   0.97
# 2015-01-03      Ahmedabad    NaN    NaN  17.40  19.30  29.70    NaN  17.40
# 2015-01-04      Ahmedabad    NaN    NaN   1.70  18.48  17.97    NaN   1.70
# 2015-01-05      Ahmedabad    NaN    NaN  22.10  21.42  37.76    NaN  22.10
# ...                   ...    ...    ...    ...    ...    ...    ...    ...
# 2020-06-27  Visakhapatnam  15.02  50.94   7.68  25.06  19.54  12.47   0.47
# 2020-06-28  Visakhapatnam  24.38  74.09   3.42  26.06  16.53  11.99   0.52
# 2020-06-29  Visakhapatnam  22.91  65.73   3.45  29.53  18.33  10.71   0.48
# 2020-06-30  Visakhapatnam  16.64  49.97   4.05  29.26  18.80  10.03   0.52
# 2020-07-01  Visakhapatnam  15.00  66.00   0.40  26.85  14.05   5.20   0.59
#
# ...

# %%
# printing first column of df
df.iloc[:,0]
# Out:
# Date
# 2015-01-01        Ahmedabad
# 2015-01-02        Ahmedabad
# 2015-01-03        Ahmedabad
# 2015-01-04        Ahmedabad
# 2015-01-05        Ahmedabad
#                   ...
# 2020-06-27    Visakhapatnam
# 2020-06-28    Visakhapatnam
# 2020-06-29    Visakhapatnam
# 2020-06-30    Visakhapatnam
# 2020-07-01    Visakhapatnam
# Name: City, Length: 29531, dtype: object

# %%
df.columns
# Out:
# Index(['City', 'PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO', 'SO2', 'O3',
#        'Benzene', 'Toluene', 'Xylene', 'AQI', 'AQI_Bucket'],
#       dtype='object')

# %%
df['PM2.5'].describe()
# Out:
# count    24933.000000
# mean        67.450578
# std         64.661449
# min          0.040000
# 25%         28.820000
# 50%         48.570000
# 75%         80.590000
# max        949.990000
# Name: PM2.5, dtype: float64

# %%
temp = df.copy()
#temp.iloc[:, 1:13] = temp.groupby('City').transform(lambda x: x.fillna(x.mean()))

temp.iloc[:, 1:13] = temp.iloc[:, 1:13].apply(lambda col: col.fillna(col.mean()), axis=0)

#Fills missing values in columns 1 to 12 based on the mean of each group defined by the "City" column.
# It replaces missing values with the average value of the non-missing values within the same city.

# %%
temp.iloc[:, 1:13] = temp.iloc[:, 1:13].fillna(temp.iloc[:, 1:13].mean())
temp

## Fills any remaining missing values in columns 1 to 12 with the overall mean of each respective column.
# This ensures that if there are still missing values in these columns after the group-wise imputation,
# they are now filled with the average value of their respective columns.
# Out:
#                      City      PM2.5        PM10     NO    NO2    NOx  \
# Date
# 2015-01-01      Ahmedabad  67.450578  118.127103   0.92  18.22  17.15
# 2015-01-02      Ahmedabad  67.450578  118.127103   0.97  15.69  16.46
# 2015-01-03      Ahmedabad  67.450578  118.127103  17.40  19.30  29.70
# 2015-01-04      Ahmedabad  67.450578  118.127103   1.70  18.48  17.97
# 2015-01-05      Ahmedabad  67.450578  118.127103  22.10  21.42  37.76
# ...                   ...        ...         ...    ...    ...    ...
# 2020-06-27  Visakhapatnam  15.020000   50.940000   7.68  25.06  19.54
# 2020-06-28  Visakhapatnam  24.380000   74.090000   3.42  26.06  16.53
# 2020-06-29  Visakhapatnam  22.910000   65.730000   3.45  29.53  18.33
# 2020-06-30  Visakhapatnam  16.640000   49.970000   4.05  29.26  18.80
# 2020-07-01  Visakhapatnam  15.000000   66.000000   0.40  26.85  14.05
#
#                   NH3     CO    SO2      O3  Benzene    Toluene    Xylene  \
# Date
# ...

# %%
df = temp.copy()
df
# Out:
#                      City      PM2.5        PM10     NO    NO2    NOx  \
# Date
# 2015-01-01      Ahmedabad  67.450578  118.127103   0.92  18.22  17.15
# 2015-01-02      Ahmedabad  67.450578  118.127103   0.97  15.69  16.46
# 2015-01-03      Ahmedabad  67.450578  118.127103  17.40  19.30  29.70
# 2015-01-04      Ahmedabad  67.450578  118.127103   1.70  18.48  17.97
# 2015-01-05      Ahmedabad  67.450578  118.127103  22.10  21.42  37.76
# ...                   ...        ...         ...    ...    ...    ...
# 2020-06-27  Visakhapatnam  15.020000   50.940000   7.68  25.06  19.54
# 2020-06-28  Visakhapatnam  24.380000   74.090000   3.42  26.06  16.53
# 2020-06-29  Visakhapatnam  22.910000   65.730000   3.45  29.53  18.33
# 2020-06-30  Visakhapatnam  16.640000   49.970000   4.05  29.26  18.80
# 2020-07-01  Visakhapatnam  15.000000   66.000000   0.40  26.85  14.05
#
#                   NH3     CO    SO2      O3  Benzene    Toluene    Xylene  \
# Date
# ...

# %%
df.isnull().sum()
# Out:
# City             0
# PM2.5            0
# PM10             0
# NO               0
# NO2              0
# NOx              0
# NH3              0
# CO               0
# SO2              0
# O3               0
# Benzene          0
# Toluene          0
# Xylene           0
# AQI           4681
# AQI_Bucket    4681
# dtype: int64

# %%
sns.heatmap(df.isnull(),yticklabels=False,cmap='plasma')
# Out:
# <Axes: ylabel='Date'>

# %% [markdown]
# ## Finding unknown value of AQI

# %%
# PM10 Sub-Index calculation
def get_PM10_subindex(x):
    if x <= 100:
        return x
    elif x > 100 and x <= 250:
        return 100 + (x - 100) * 100 / 150
    elif x > 250 and x <= 350:
        return 200 + (x - 250)
    elif x > 350 and x <= 430:
        return 300 + (x - 350) * 100 / 80
    elif x > 430:
        return 400 + (x - 430) * 100 / 80
    else:
        return 0

df["PM10_SubIndex"] = df["PM10"].astype(int).apply(lambda x: get_PM10_subindex(x))

# %% [markdown]
# ![Screenshot 2023-11-27 181121.png](data:image/png;base64,...)

# %%
# PM2.5 Sub-Index calculation
def get_PM25_subindex(x):
    if x <= 30:
        return x * 50 / 30
    elif x > 30 and x <= 60:
        return 50 + (x - 30) * 50 / 30
    elif x > 60 and x <= 90:
        return 100 + (x - 60) * 100 / 30
    elif x > 90 and x <= 120:
        return 200 + (x - 90) * 100 / 30
    elif x > 120 and x <= 250:
        return 300 + (x - 120) * 100 / 130
    elif x > 250:
        return 400 + (x - 250) * 100 / 130
    else:
        return 0

df["PM2.5_SubIndex"] = df["PM2.5"].astype(int).apply(lambda x: get_PM25_subindex(x))

# %%
# SO2 Sub-Index calculation
def get_SO2_subindex(x):
    if x <= 40:
        return x * 50 / 40
    elif x > 40 and x <= 80:
        return 50 + (x - 40) * 50 / 40
    elif x > 80 and x <= 380:
        return 100 + (x - 80) * 100 / 300
    elif x > 380 and x <= 800:
        return 200 + (x - 380) * 100 / 420
    elif x > 800 and x <= 1600:
        return 300 + (x - 800) * 100 / 800
    elif x > 1600:
        return 400 + (x - 1600) * 100 / 800
    else:
        return 0

df["SO2_SubIndex"] = df["SO2"].astype(int).apply(lambda x: get_SO2_subindex(x))

# %%
# NOx Sub-Index calculation
def get_NOx_subindex(x):
    if x <= 40:
        return x * 50 / 40
    elif x > 40 and x <= 80:
        return 50 + (x - 40) * 50 / 40
    elif x > 80 and x <= 180:
        return 100 + (x - 80) * 100 / 100
    elif x > 180 and x <= 280:
        return 200 + (x - 180) * 100 / 100
    elif x > 280 and x <= 400:
        return 300 + (x - 280) * 100 / 120
    elif x > 400:
        return 400 + (x - 400) * 100 / 120
    else:
        return 0

df["NOx_SubIndex"] = df["NOx"].astype(int).apply(lambda x: get_NOx_subindex(x))

# %%
# NH3 Sub-Index calculation
def get_NH3_subindex(x):
    if x <= 200:
        return x * 50 / 200
    elif x > 200 and x <= 400:
        return 50 + (x - 200) * 50 / 200
    elif x > 400 and x <= 800:
        return 100 + (x - 400) * 100 / 400
    elif x > 800 and x <= 1200:
        return 200 + (x - 800) * 100 / 400
    elif x > 1200 and x <= 1800:
        return 300 + (x - 1200) * 100 / 600
    elif x > 1800:
        return 400 + (x - 1800) * 100 / 600
    else:
        return 0

df["NH3_SubIndex"] = df["NH3"].astype(int).apply(lambda x: get_NH3_subindex(x))

# %%
# CO Sub-Index calculation
def get_CO_subindex(x):
    if x <= 1:
        return x * 50 / 1
    elif x > 1 and x <= 2:
        return 50 + (x - 1) * 50 / 1
    elif x > 2 and x <= 10:
        return 100 + (x - 2) * 100 / 8
    elif x > 10 and x <= 17:
        return 200 + (x - 10) * 100 / 7
    elif x > 17 and x <= 34:
        return 300 + (x - 17) * 100 / 17
    elif x > 34:
        return 400 + (x - 34) * 100 / 17
    else:
        return 0

df["CO_SubIndex"] = df["CO"].astype(int).apply(lambda x: get_CO_subindex(x))

# %%
# O3 Sub-Index calculation
def get_O3_subindex(x):
    if x <= 50:
        return x * 50 / 50
    elif x > 50 and x <= 100:
        return 50 + (x - 50) * 50 / 50
    elif x > 100 and x <= 168:
        return 100 + (x - 100) * 100 / 68
    elif x > 168 and x <= 208:
        return 200 + (x - 168) * 100 / 40
    elif x > 208 and x <= 748:
        return 300 + (x - 208) * 100 / 539
    elif x > 748:
        return 400 + (x - 400) * 100 / 539
    else:
        return 0

df["O3_SubIndex"] = df["O3"].astype(int).apply(lambda x: get_O3_subindex(x))

# %%
# Calculating unknown values of AQI

df["AQI"] = df["AQI"].fillna(round(df[["PM2.5_SubIndex", "PM10_SubIndex", "SO2_SubIndex", "NOx_SubIndex","NH3_SubIndex", "CO_SubIndex", "O3_SubIndex"]].max(axis = 1)))

# %%
df
# Out:
#                      City      PM2.5        PM10     NO    NO2    NOx  \
# Date
# 2015-01-01      Ahmedabad  67.450578  118.127103   0.92  18.22  17.15
# 2015-01-02      Ahmedabad  67.450578  118.127103   0.97  15.69  16.46
# 2015-01-03      Ahmedabad  67.450578  118.127103  17.40  19.30  29.70
# 2015-01-04      Ahmedabad  67.450578  118.127103   1.70  18.48  17.97
# 2015-01-05      Ahmedabad  67.450578  118.127103  22.10  21.42  37.76
# ...                   ...        ...         ...    ...    ...    ...
# 2020-06-27  Visakhapatnam  15.020000   50.940000   7.68  25.06  19.54
# 2020-06-28  Visakhapatnam  24.380000   74.090000   3.42  26.06  16.53
# 2020-06-29  Visakhapatnam  22.910000   65.730000   3.45  29.53  18.33
# 2020-06-30  Visakhapatnam  16.640000   49.970000   4.05  29.26  18.80
# 2020-07-01  Visakhapatnam  15.000000   66.000000   0.40  26.85  14.05
#
#                   NH3     CO    SO2      O3  ...    Xylene    AQI  \
# Date                                         ...
# ...

# %%
df = df.drop(['AQI_Bucket'], axis=1)

# %%
df.head()
# Out:
#                  City      PM2.5        PM10     NO    NO2    NOx        NH3  \
# Date
# 2015-01-01  Ahmedabad  67.450578  118.127103   0.92  18.22  17.15  23.483476
# 2015-01-02  Ahmedabad  67.450578  118.127103   0.97  15.69  16.46  23.483476
# 2015-01-03  Ahmedabad  67.450578  118.127103  17.40  19.30  29.70  23.483476
# 2015-01-04  Ahmedabad  67.450578  118.127103   1.70  18.48  17.97  23.483476
# 2015-01-05  Ahmedabad  67.450578  118.127103  22.10  21.42  37.76  23.483476
#
#                CO    SO2      O3  ...  Toluene  Xylene    AQI  PM10_SubIndex  \
# Date                              ...
# 2015-01-01   0.92  27.64  133.36  ...     0.02    0.00  149.0          112.0
# 2015-01-02   0.97  24.55   34.06  ...     5.50    3.77  123.0          112.0
# 2015-01-03  17.40  29.07   30.70  ...    16.40    2.25  300.0          112.0
# 2015-01-04   1.70  18.59   36.08  ...    10.14    1.00  123.0          112.0
# ...

# %%
df.columns
# Out:
# Index(['City', 'PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO', 'SO2', 'O3',
#        'Benzene', 'Toluene', 'Xylene', 'AQI', 'PM10_SubIndex',
#        'PM2.5_SubIndex', 'SO2_SubIndex', 'NOx_SubIndex', 'NH3_SubIndex',
#        'CO_SubIndex', 'O3_SubIndex'],
#       dtype='object')

# %%
datafram = df.iloc[:, 1:]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns;
plt.figure(figsize=(20,20))
cor = datafram.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.PuBu)
plt.show()

# %% [markdown]
# # Spliting the data 🫡

# %%
df.head()
# Out:
#                  City      PM2.5        PM10     NO    NO2    NOx        NH3  \
# Date
# 2015-01-01  Ahmedabad  67.450578  118.127103   0.92  18.22  17.15  23.483476
# 2015-01-02  Ahmedabad  67.450578  118.127103   0.97  15.69  16.46  23.483476
# 2015-01-03  Ahmedabad  67.450578  118.127103  17.40  19.30  29.70  23.483476
# 2015-01-04  Ahmedabad  67.450578  118.127103   1.70  18.48  17.97  23.483476
# 2015-01-05  Ahmedabad  67.450578  118.127103  22.10  21.42  37.76  23.483476
#
#                CO    SO2      O3  ...  Toluene  Xylene    AQI  PM10_SubIndex  \
# Date                              ...
# 2015-01-01   0.92  27.64  133.36  ...     0.02    0.00  149.0          112.0
# 2015-01-02   0.97  24.55   34.06  ...     5.50    3.77  123.0          112.0
# 2015-01-03  17.40  29.07   30.70  ...    16.40    2.25  300.0          112.0
# 2015-01-04   1.70  18.59   36.08  ...    10.14    1.00  123.0          112.0
# ...

# %% [markdown]
# ## One-hot encoding

# %%
# importing one hot encoder
from sklearn.preprocessing import OneHotEncoder

# %%
# Assuming newdf is your original DataFrame
onehotencoder = OneHotEncoder()
ohe = OneHotEncoder(handle_unknown='ignore', sparse_output = False).set_output(transform='pandas')

oheData = ohe.fit_transform(df[['City']])

# %%
test = df.copy()
test = pd.concat([test, oheData], axis=1).drop(columns=['City'])
test
#df = pd.concat([df, oheData], axis=1).drop(columns=['City'])
#df.head()
# Out:
#                 PM2.5        PM10     NO    NO2    NOx        NH3     CO  \
# Date
# 2015-01-01  67.450578  118.127103   0.92  18.22  17.15  23.483476   0.92
# 2015-01-02  67.450578  118.127103   0.97  15.69  16.46  23.483476   0.97
# 2015-01-03  67.450578  118.127103  17.40  19.30  29.70  23.483476  17.40
# 2015-01-04  67.450578  118.127103   1.70  18.48  17.97  23.483476   1.70
# 2015-01-05  67.450578  118.127103  22.10  21.42  37.76  23.483476  22.10
# ...               ...         ...    ...    ...    ...        ...    ...
# 2020-06-27  15.020000   50.940000   7.68  25.06  19.54  12.470000   0.47
# 2020-06-28  24.380000   74.090000   3.42  26.06  16.53  11.990000   0.52
# 2020-06-29  22.910000   65.730000   3.45  29.53  18.33  10.710000   0.48
# 2020-06-30  16.640000   49.970000   4.05  29.26  18.80  10.030000   0.52
# 2020-07-01  15.000000   66.000000   0.40  26.85  14.05   5.200000   0.59
#
#               SO2      O3  Benzene  ...  City_Jorapokhar  City_Kochi  \
# ...

# %%
print(df['City'].unique().sum())
# Out:
# AhmedabadAizawlAmaravatiAmritsarBengaluruBhopalBrajrajnagarChandigarhChennaiCoimbatoreDelhiErnakulamGurugramGuwahatiHyderabadJaipurJorapokharKochiKolkataLucknowMumbaiPatnaShillongTalcherThiruvananthapuramVisakhapatnam
# Index(['PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO', 'SO2', 'O3',
#        'Benzene', 'Toluene', 'Xylene'],
#       dtype='object')

# %% [markdown]
# ## Dividing into Train and Test 😉

# %%
# Assuming df is your original DataFrame
X = df.iloc[:,1:13].copy()
y = df['AQI']
X
# Out:
#                 PM2.5        PM10     NO    NO2    NOx        NH3     CO  \
# Date
# 2015-01-01  67.450578  118.127103   0.92  18.22  17.15  23.483476   0.92
# 2015-01-02  67.450578  118.127103   0.97  15.69  16.46  23.483476   0.97
# 2015-01-03  67.450578  118.127103  17.40  19.30  29.70  23.483476  17.40
# 2015-01-04  67.450578  118.127103   1.70  18.48  17.97  23.483476   1.70
# 2015-01-05  67.450578  118.127103  22.10  21.42  37.76  23.483476  22.10
# ...               ...         ...    ...    ...    ...        ...    ...
# 2020-06-27  15.020000   50.940000   7.68  25.06  19.54  12.470000   0.47
# 2020-06-28  24.380000   74.090000   3.42  26.06  16.53  11.990000   0.52
# 2020-06-29  22.910000   65.730000   3.45  29.53  18.33  10.710000   0.48
# 2020-06-30  16.640000   49.970000   4.05  29.26  18.80  10.030000   0.52
# 2020-07-01  15.000000   66.000000   0.40  26.85  14.05   5.200000   0.59
#
#               SO2      O3  Benzene    Toluene    Xylene
# Date
# ...

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.30, random_state=42)

# %% [markdown]
# ## Standering the data 🔥

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
# dumping pickle file for front-end prediction
import pickle
pickle.dump(scaler, open('scalingAqi.pkl', 'wb'))

# %%
# save for future predication
save = X_train[0]
saveRes = y_train[0]
print(save, "\n\n", saveRes)
# Out:
# [ 1.12844248e-03  7.73556027e-03 -8.42672219e-04  2.13883583e-04
#  -5.41745438e-01  6.05438643e-03 -3.29618747e-01  1.12378344e-03
#   3.33920151e-03 -2.29313898e-01 -5.16561365e-01 -7.47935082e-01]
#
#  123.0
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5756\4082417328.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   saveRes = y_train[0]

# %% [markdown]
# # Traning Model

# %%
from sklearn.linear_model import LinearRegression

# %%
regression = LinearRegression()
regression.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
regression.coef_
# Out:
# array([64.19407327, 22.77424729, -3.84157139,  5.93751531,  5.88369467,
#        -1.23382348, 74.85350783, 10.57107705,  3.7119677 , -0.97244081,
#         0.97391817,  0.21810943])

# %%
y_pred = regression.predict(X_test)
print(y_pred)
# Out:
# [137.01856489 137.01856489 129.0202822  ...  99.61410261  70.09814101
#  127.40541597]

# %%
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
# Out:
# 0.8498375144997627

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test, y_pred)
print(f'Mean Squared Error: {mse}')
# Out:
# Mean Squared Error: 2445.089948363539

# %%
plt.scatter(y_test, y_pred)

# %%
# It is save above
print(save)
res = regression.predict([save])
print("Predicat result : " ,res ,"\n\nActual result", saveRes)
# Out:
# [ 1.12844248e-03  7.73556027e-03 -8.42672219e-04  2.13883583e-04
#  -5.41745438e-01  6.05438643e-03 -3.29618747e-01  1.12378344e-03
#   3.33920151e-03 -2.29313898e-01 -5.16561365e-01 -7.47935082e-01]
# Predicat result :  [133.41098686]
#
# Actual result 123.0

# %% [markdown]
# ## Pickle dump

# %%
import pickle
pickle.dump(regression, open('regmodelAqi.pkl', 'wb'))
